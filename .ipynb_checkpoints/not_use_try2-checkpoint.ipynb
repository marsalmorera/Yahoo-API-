# %%
import requests
import pandas as pd 

url = "https://yahoo-finance-api-data.p.rapidapi.com/market/equity"

querystring = {"screenerId":"MOST_ACTIVES","region":"us","offset":"180","limit":"250"} #"offset": str(i)

headers = {
	"x-rapidapi-key": "8dc7f3f670mshf5316a9ce715732p14098ajsnf6ee01f4a31e",
	"x-rapidapi-host": "yahoo-finance-api-data.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
status_data = response.json()
data = status_data['data']['quotes']
data
# Out:
# [{'language': 'en-US',
#   'region': 'US',
#   'quoteType': 'EQUITY',
#   'typeDisp': 'Equity',
#   'quoteSourceName': 'Delayed Quote',
#   'triggerable': False,
#   'customPriceAlertConfidence': 'LOW',
#   'lastClosePriceToNNWCPerShare': -0.0502248875263181,
#   'currency': 'USD',
#   'regularMarketChangePercent': 7.57991,
#   'exchange': 'NYQ',
#   'hasPrePostMarketData': True,
#   'firstTradeDateMilliseconds': 754065000000,
#   'priceHint': 2,
#   'postMarketChangePercent': 0,
#   'postMarketTime': 1728691200,
#   'postMarketPrice': 11.78,
#   'postMarketChange': 0,
#   'regularMarketChange': 0.83,
#   'regularMarketTime': 1728676802,
#   'regularMarketPrice': 11.78,
#   'regularMarketDayHigh': 11.83,
#   'regularMarketDayRange': '10.98 - 11.83',
#   'regularMarketDayLow': 10.98,
#   'regularMarketVolume': 5233268,
#   'regularMarketPreviousClose': 10.95,
#   'bid': 11.45,
#   'ask': 11.77,
#   'bidSize': 14,
#   'askSize': 10,
#   'market': 'us_market',
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#    language region quoteType typeDisp         quoteSourceName  triggerable  \
# 0     en-US     US    EQUITY   Equity           Delayed Quote        False
# 1     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 2     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 3     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 4     en-US     US    EQUITY   Equity           Delayed Quote        False
# 5     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 6     en-US     US    EQUITY   Equity           Delayed Quote        False
# 7     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 8     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 9     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 10    en-US     US    EQUITY   Equity           Delayed Quote        False
# ...

# %%
df.columns
# Out:
# Index(['language', 'region', 'quoteType', 'typeDisp', 'quoteSourceName',
#        'triggerable', 'customPriceAlertConfidence',
#        'lastClosePriceToNNWCPerShare', 'currency',
#        'regularMarketChangePercent', 'exchange', 'hasPrePostMarketData',
#        'firstTradeDateMilliseconds', 'priceHint', 'postMarketChangePercent',
#        'postMarketTime', 'postMarketPrice', 'postMarketChange',
#        'regularMarketChange', 'regularMarketTime', 'regularMarketPrice',
#        'regularMarketDayHigh', 'regularMarketDayRange', 'regularMarketDayLow',
#        'regularMarketVolume', 'regularMarketPreviousClose', 'bid', 'ask',
#        'bidSize', 'askSize', 'market', 'messageBoardId', 'fullExchangeName',
#        'longName', 'financialCurrency', 'regularMarketOpen',
#        'averageDailyVolume3Month', 'averageDailyVolume10Day',
#        'fiftyTwoWeekLowChange', 'fiftyTwoWeekLowChangePercent',
#        'fiftyTwoWeekRange', 'fiftyTwoWeekHighChange',
# ...

# %%
# Try 
for i in range(0, 180, 20):
# Try 2 
data_df = []
for i in range(0, 180, 20):
    status_data = response.json()
    stat_data = status_data['data']['quotes']
    df = pd.DataFrame(stat_data)
    all_data.append(data)
# Try 3
all_data= []
for i in range(1, 180, 20):
    data = status_data['data']['quotes']
    df = pd.DataFrame(data)
    all_data.append(data)
