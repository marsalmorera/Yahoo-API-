# %%
# IMPORTANT
# Check why in MOST_ACTIVES just appear 75 today. but 180 the last saturday and sunday. 
import requests
import pandas as pd 

url = "https://yahoo-finance-api-data.p.rapidapi.com/market/equity"

headers = {
	"x-rapidapi-key": "8dc7f3f670mshf5316a9ce715732p14098ajsnf6ee01f4a31e",
	"x-rapidapi-host": "yahoo-finance-api-data.p.rapidapi.com"
}

all_data = []
for i in range(0, 250, 20):
    querystring = {"screenerId": "MOST_ACTIVES", "region": "us", "offset": i, "limit": "250"}
    response = requests.get(url, headers=headers, params=querystring)
    if response.status_code == 200:
        status_data = response.json()
        data = status_data['data']['quotes']
        data1 = pd.DataFrame(data)
        all_data.append(data1)
    else:
        print('Error')
df = pd.concat(all_data, ignore_index=True)

# %%
df
# Out:
#    language region quoteType typeDisp         quoteSourceName  triggerable  \
# 0     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 1     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 2     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 3     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 4     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# ..      ...    ...       ...      ...                     ...          ...
# 73    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 74    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 75    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 76    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 77    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
#
#    customPriceAlertConfidence  lastCloseTevEbitLtm  \
# ...

# %%
status_data = response.json()
data = status_data['data']['quotes']
data

# %%
df = pd.DataFrame(data)
df

# %%
data.keys()
